# %%
import requests
import pandas as pd
import time

# %%
# API Call to NVD to download colleciton of vulnerabilities as a json
cveData01 = requests.get('https://services.nvd.nist.gov/rest/json/cves/1.0').json()

# %%
cveData01
# Out:
# {'resultsPerPage': 20,
#  'startIndex': 0,
#  'totalResults': 159806,
#  'result': {'CVE_data_type': 'CVE',
#   'CVE_data_format': 'MITRE',
#   'CVE_data_version': '4.0',
#   'CVE_data_timestamp': '2021-09-02T01:54Z',
#   'CVE_Items': [{'cve': {'data_type': 'CVE',
#      'data_format': 'MITRE',
#      'data_version': '4.0',
#      'CVE_data_meta': {'ID': 'CVE-2021-31798', 'ASSIGNER': 'cve@mitre.org'},
#      'problemtype': {'problemtype_data': [{'description': []}]},
#      'references': {'reference_data': [{'url': 'https://www.cyberark.com/resources/blog',
#         'name': 'https://www.cyberark.com/resources/blog',
#         'refsource': 'MISC',
#         'tags': []},
#        {'url': 'http://seclists.org/fulldisclosure/2021/Sep/3',
#         'name': 'http://seclists.org/fulldisclosure/2021/Sep/3',
#         'refsource': 'MISC',
#         'tags': []},
#        {'url': 'https://korelogic.com/Resources/Advisories/KL-001-2021-010.txt',
# ...
